# %% [markdown]
# NAMA : ARIO SYAWAL MUHAMMAD
# NIM : 1103201243

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = "FuelConsumptionCo2.csv"
df = pd.read_csv(dataset)
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
sns.countplot( x = df['CO2EMISSIONS'] )
# Out:
# <Axes: xlabel='CO2EMISSIONS', ylabel='count'>

# %%
sns.distplot(df['FUELCONSUMPTION_CITY'])
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_18544\4097341991.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FUELCONSUMPTION_CITY'])
# <Axes: xlabel='FUELCONSUMPTION_CITY', ylabel='Density'>

# %%
sns.boxplot(df['FUELCONSUMPTION_CITY'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x= df['FUELCONSUMPTION_CITY'], y = df['FUELCONSUMPTION_HWY']  , hue = df['FUELCONSUMPTION_COMB'] , style = df['FUELCONSUMPTION_COMB_MPG'] , size = df['CO2EMISSIONS'])
plt.show ()
df['FUELCONSUMPTION_CITY'].min()
# Out:
# 4.6

# %%
sns.barplot (x = df['FUELCONSUMPTION_HWY'] , y = df['FUELCONSUMPTION_CITY'] , hue = df['CO2EMISSIONS'])
# Out:
# <Axes: xlabel='FUELCONSUMPTION_HWY', ylabel='FUELCONSUMPTION_CITY'>

# %%
sns.boxplot( x = df['FUELCONSUMPTION_HWY'] , y = df['FUELCONSUMPTION_CITY'] , hue = df['CO2EMISSIONS'] )
# Out:
# <Axes: xlabel='FUELCONSUMPTION_HWY', ylabel='FUELCONSUMPTION_CITY'>
